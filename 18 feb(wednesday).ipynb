# %%
i=2
while i<=8:
    print(i)
    i+=2
# Out:
# 2
# 4
# 6
# 8

# %%
count = 20
while count > 0:
    print(count)
    count -= 2
# Out:
# 20
# 18
# 16
# 14
# 12
# 10
# 8
# 6
# 4
# 2

# %%
count= 10
while count >=4:
    print (count)
    count-=2
# Out:
# 10
# 8
# 6
# 4

# %%
i = 1
while i <= 5:
    if i == 3:
        break
    print(i)
    i += 1
# Out:
# 1
# 2

# %%
num = 2
while num <= 10:
    print(num)
    num += 2
# Out:
# 2
# 4
# 6
# 8
# 10

# %%
x=1
while i<=5:
    if x==2:
        break
    print (x)
    x+=1
# Out:
# 1
