# %%
Name = "Ali"
print(Name)
# Out:
# Ali

# %%
"hello"
print("hello")
# Out:
# hello

# %%
x=5
y=10
print(x+y)
# Out:
# 15

# %%
x=10
y=7
print(x-y)
# Out:
# 3

# %%
z=10
y=3
print(z*y)
# Out:
# 30
