# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt 

df=pd.read_csv("d:\python\student_data_clean.csv")
# Out:
# <>:6: SyntaxWarning: invalid escape sequence '\p'
# <>:6: SyntaxWarning: invalid escape sequence '\p'
# C:\Users\momin\AppData\Local\Temp\ipykernel_3876\3594196534.py:6: SyntaxWarning: invalid escape sequence '\p'
#   df=pd.read_csv("d:\python\student_data_clean.csv")

# %%
df.head()
# Out:
#    Student_ID       Name  Age  Gender Department  Semester  CGPA  \
# 0        1001  Student_0   24   Other       Math         3   NaN
# 1        1002  Student_1   21  Female         EE         1  3.94
# 2        1003  Student_2   22   Other         EE         5  2.44
# 3        1004  Student_3   24    Male         EE         4  3.47
# 4        1005  Student_4   20    Male         CS         2  3.53
#
#    Attendance_Rate  Scholarship Admission_Date  Midterm_Marks  Final_Marks  \
# 0             61.0        False     2021-09-11             26           33
# 1             98.0        False     2020-01-26              0           39
# 2             66.0        False     2022-08-14             20           46
# 3             91.0        False     2021-02-24             19           14
# 4             79.0        False     2021-10-24             12           10
#
#          City  Study_Hours_Per_Day    Fees_Paid
# 0      Multan                   10          NaN
# 1      Lahore                    5  Installment
# 2  Faisalabad                    7         Full
# 3  Faisalabad                    8         Full
# 4     Karachi                    3  Installment

# %%
pd.pivot_table(df,
                 values=['CGPA',"Scholarship"],
                              index="Department",
                              columns="Gender",
                              aggfunc="mean" )
# Out:
#                 CGPA                     Scholarship
# Gender        Female      Male     Other      Female      Male     Other
# Department
# BBA         3.052000  3.034026  3.033279    0.203125  0.250000  0.206349
# CS          2.991964  3.149206  3.068592    0.220339  0.250000  0.240000
# EE          3.086415  3.035593  3.034340    0.177419  0.245902  0.181818
# Math        3.004545  3.176250  2.986627    0.182927  0.181818  0.206897
# Physics     2.991618  3.029865  3.055500    0.257143  0.120000  0.134328

# %%
df.columns
# Out:
# Index(['Student_ID', 'Name', 'Age', 'Gender', 'Department', 'Semester', 'CGPA',
#        'Attendance_Rate', 'Scholarship', 'Admission_Date', 'Midterm_Marks',
#        'Final_Marks', 'City', 'Study_Hours_Per_Day', 'Fees_Paid'],
#       dtype='str')

# %%
plt.figure(figsize=(5,5))
sns.barplot(data=df,x="Department",y="Student_ID",hue="Gender")
plt.show()

# %%
plt.Figure(figsize=(8,4))
sns.barplot(data=df,x="Department",y="Attendance_Rate")
plt.show()
