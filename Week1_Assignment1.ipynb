# %%
#Assignment #01
name = input("What is your name? ")

birth_year = int(input("What year were you born? "))

current_age = int(input("How old are you right now? "))

current_year = 2026
year_at_100 = (100 - current_age) + current_year
print(f"You will turn 100 in the year {year_at_100}.")

lucky_number = float(input("What is your lucky number? "))

print("\n--- Personal Assistant Summary ---")
print(f"Hello {name}!")
print(f"Born in: {birth_year}")
print(f"Current age: {current_age}")
print(f"You'll be a century old in: {year_at_100}")
print(f"Your lucky number is: {lucky_number}")
# Out:
# You will turn 100 in the year 2106.
#
# --- Personal Assistant Summary ---
# Hello Momina!
# Born in: 2005
# Current age: 20
# You'll be a century old in: 2106
# Your lucky number is: 7.0
