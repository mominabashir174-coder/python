# %%
import math

# 1. Function to get numbers from user
def get_numbers():
    numbers_str = input("Enter numbers separated by spaces: ")
    numbers_list = [float(num) for num in numbers_str.split()]
    return numbers_list

# 2. Function to calculate mean
def calculate_mean(data):
    return sum(data) / len(data)

# 3. Function to calculate sample variance
def calculate_variance(data, mean):
    n = len(data)
    variance = sum((x - mean) ** 2 for x in data) / (n - 1)
    return variance

# 4. Function to calculate standard deviation
def calculate_std_dev(variance):
    return math.sqrt(variance)


data = get_numbers()
mean = calculate_mean(data)
variance = calculate_variance(data, mean)
std_dev = calculate_std_dev(variance)

print("\n--- Statistical Analysis ---")
print(f"Data: {data}")
print(f"Mean: {mean:.2f}")
print(f"Variance: {variance:.2f}")
print(f"Standard Deviation: {std_dev:.2f}")
# Out:
# --- Statistical Analysis ---
# Data: [1.0, 4.0]
# Mean: 2.50
# Variance: 4.50
# Standard Deviation: 2.12
