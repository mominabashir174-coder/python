# %%
age = 20
local = True
if age >= 18:
    if local:
        print("Approved")
if age >= 18:
    if not local:
        print("Need citizenship")
num = 15
if num > 0: 
    if num % 2 == 0:
        print("Positive even")
    else:
        print("Positive odd")
marks = 85
if marks >= 50:
    if marks >= 80:
        print("A grade")
    else:
        print("Pass")
# Out:
# Approved
# Positive odd
# A grade

# %%
age = 20
citizen = True
if age >= 18:
    if citizen:
        print("Eligible")
if age >= 18:
    if not citizen:
        print("Need citizenship")
# Out:
# Eligible

# %%
num = 15
if num > 0:
    if num % 2 == 0:
        print("Positive even")
    else:
        print("Positive odd")
# Out:
# Positive odd

# %%
marks = 85
if marks >= 50:
    if marks >= 80:
        print("A grade")
    else:
        print("Pass")
# Out:
# A grade

# %%
marks = 19
if num >= 10:
  if marks >= 25:
   print ("accept")
else :
  print("not aepted")

# %%
for i in range (1,11):
  for j in range (1):
     if i% 2 ==0:
        print (i)
# Out:
# 2
# 4
# 6
# 8
# 10

# %%
x=20
if x > 10:
  print ("greater")
if x < 10:
 print ("small")
else :
   print("not small")
if x == 10:
  print ("10")
elif x > 10:
 print ("big")
else: print("others")
for i in range(5):
    if i == 3:
        break
    for i in range(5):
     if  i == 2:
        continue
     print(i)
for i in range(3):
    pass
# Out:
# greater
# not small
# big
# 0
# 1
# 3
# 4
# 0
# 1
# 3
# 4
# 0
# 1
# 3
# 4
