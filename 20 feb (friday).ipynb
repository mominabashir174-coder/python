# %%
add = lambda a, b: a + b
print(add(2, 3))
# Out:
# 5

# %%
square = lambda x: x*x
print(square(4))
# Out:
# 16

# %%
f = lambda: "Hello"
print(f())
# Out:
# Hello

# %%
nums = [5,1,4]
print(sorted(nums, key=lambda x: -x))
# Out:
# [5, 4, 1]

# %%
def greet():
    print("Hello") 
greet()
# Out:
# Hello

# %%
def subtract(a, b):
    return a - b
print(subtract(2, 3))
# Out:
# -1

# %%
def mutliply (c,d):
    return c * d 
print (mutliply (5, 5))
# Out:
# 25

# %%
x = 10
def change():
    x = 5
    print(x)
change()
print(x)
# Out:
# 5
# 10

# %%
def info (name,age):
    print(name,age)
    info( "Ali",25)

# %%
def outer():
    z = 7
    def inner():
        print(z)
    inner()
outer()
# Out:
# 7
