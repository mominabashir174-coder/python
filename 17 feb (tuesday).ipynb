# %%
s="momina"
s="name"
s*3
s[3]
s[1:3]
len(s)
s.lower()
s.upper()
s.replace("am","re")
"th" in s
# Out:
# False

# %%
s= "pakistan"
s+ "country"
s*4
s[4]
s[1:5]
len(s)
s.lower()
s.upper()
s.replace ("tr","re")
"is" in s
# Out:
# True

# %%
name= input("momina") 
age= input("20")
height=("5'0")
str(100)
# This is a comment
x=int("10")+ 5
y=float (5.0)
z=bool(7)
print(x,y,z)
print("momina,20,5'0")
# Out:
# 15 5.0 True
# momina,20,5'0

# %%
name= input("momina")
age= input("20")
height=("5'0")
x= int("10") +5
y= float("5.0")
z=bool (10)
print (x,y,z)
print("momina,20")
# Out:
# 15 5.0 True
# momina,20

# %%
lst = [1, 2, 3]
lst.append(5)
lst.remove(2)
lst[0]
len(lst)
tpl=[10,20,30]
tpl[2]
# Out:
# 30

# %%
lst=[12,22,32]
lst.append(34)
print (lst)
lst[0]
print(lst [0])
tuple=[23,32,46]
print (tuple)
tuple[2]
print(tuple[2])
# Out:
# [12, 22, 32, 34]
# 12
# [23, 32, 46]
# 46

# %%
d={"name": "Ali","age": 20}
d["name"]
d["country"]="Pakistan"
len (d)
s={1,2,3,4,5}
s.add (8)
s.remove(3)
9 in s
set2= {12,13,14,15}
print (set2)
# Out:
# {12, 13, 14, 15}
